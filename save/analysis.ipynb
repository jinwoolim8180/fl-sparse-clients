# %%
import pickle
import matplotlib.pyplot as plt
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[3]C[0]L[ce].pkl', 'rb') as f:
    baseline = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[3]C[0]L[bs].pkl', 'rb') as f:
    bs = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[3]C[0]L[fl]FL[1.0].pkl', 'rb') as f:
    focal = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[3]C[1]L[ce]LLR[1.0]EP[0.001].pkl', 'rb') as f:
    climb = pickle.load(f)

plt.plot(range(0,200,5), [r[0] for r in baseline], label='Baseline')
plt.plot(range(0,200,5), [r[0] for r in bs], label='Balanced Softmax')
plt.plot(range(0,200,5), [r[0] for r in focal], label='Focal Loss')
plt.plot(range(0,200,5), [r[0] for r in climb], label='CLIMB')
plt.legend()
plt.title('β=0.2, n_minority_class=3, ρ=10')
plt.ylim(0.8, 1.0)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[3]C[0]L[ce].pkl', 'rb') as f:
    baseline = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[3]C[0]L[bs].pkl', 'rb') as f:
    bs = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[3]C[0]L[fl]FL[1.0].pkl', 'rb') as f:
    focal = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[3]C[1]L[ce]LLR[1.0]EP[0.001].pkl', 'rb') as f:
    climb = pickle.load(f)

plt.plot(range(0,200,5), [r[0] for r in baseline], label='Baseline')
plt.plot(range(0,200,5), [r[0] for r in bs], label='Balanced Softmax')
plt.plot(range(0,200,5), [r[0] for r in focal], label='Focal Loss')
plt.plot(range(0,200,5), [r[0] for r in climb], label='CLIMB')
plt.legend()
plt.title('β=1.0, n_minority_class=3, ρ=10')
plt.ylim(0.92, 0.98)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[0]C[0]L[ce].pkl', 'rb') as f:
    baseline = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[0]C[0]L[bs].pkl', 'rb') as f:
    bs = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[0]C[0]L[fl]FL[1.0].pkl', 'rb') as f:
    focal = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[0.2]M[0]C[1]L[ce]LLR[1.0]EP[0.001].pkl', 'rb') as f:
    climb = pickle.load(f)

plt.plot(range(0,200,5), [r[0] for r in baseline], label='Baseline')
plt.plot(range(0,200,5), [r[0] for r in bs], label='Balanced Softmax')
plt.plot(range(0,200,5), [r[0] for r in focal], label='Focal Loss')
plt.plot(range(0,200,5), [r[0] for r in climb], label='CLIMB')
plt.legend()
plt.title('β=0.2, n_minority_class=0')
plt.ylim(0.92, 0.98)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[0]C[0]L[ce].pkl', 'rb') as f:
    baseline = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[0]C[0]L[bs].pkl', 'rb') as f:
    bs = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[0]C[0]L[fl]FL[1.0].pkl', 'rb') as f:
    focal = pickle.load(f)
with open('./results/mnist/R[200]LR[0.01]LD[0.1]E[5]FR[1.0]C[100]WD[0.0]RH[10B[1.0]M[0]C[1]L[ce]LLR[1.0]EP[0.001].pkl', 'rb') as f:
    climb = pickle.load(f)

plt.plot(range(0,200,5), [r[0] for r in baseline], label='Baseline')
plt.plot(range(0,200,5), [r[0] for r in bs], label='Balanced Softmax')
plt.plot(range(0,200,5), [r[0] for r in focal], label='Focal Loss')
plt.plot(range(0,200,5), [r[0] for r in climb], label='CLIMB')
plt.legend()
plt.title('β=1.0, n_minority_class=0')
plt.ylim(0.95, 0.99)
plt.show()
